# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# Test set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'D:\\Fruit_Vegetable_Recognition\\test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# Loading Model

# %%
cnn = tf.keras.models.load_model('D:\\Fruit_Vegetable_Recognition\\trained_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# Visualising and Performing Prediction on Single image

# %%
import cv2
image_path = r"D:\Fruit_Vegetable_Recognition\train\capsicum\Image_29.jpg"
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step

# %%
print(predictions)
# Out:
# [[3.4903526e-02 1.6368713e-04 4.3010172e-02 8.0364611e-04 7.6723326e-04
#   1.0489414e-02 9.3475683e-03 7.3909177e-03 3.1362459e-02 9.1905624e-04
#   1.9455091e-04 1.0574013e-02 1.8038577e-01 1.9125013e-02 3.9034098e-02
#   1.3242553e-03 1.0988973e-04 1.5317515e-04 1.7770274e-04 2.0212661e-04
#   1.4925769e-01 8.7281235e-04 1.3669646e-01 1.2315931e-04 8.3394448e-04
#   1.0838480e-02 1.2839742e-01 1.1267084e-02 1.1258998e-02 4.5057699e-02
#   7.4280608e-05 4.3561155e-04 4.2064134e-02 4.7393344e-02 1.4661732e-02
#   1.0328769e-02]]

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 12

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a garlic
